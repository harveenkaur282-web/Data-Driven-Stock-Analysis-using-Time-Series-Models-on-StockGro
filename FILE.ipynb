# %%
from src.data.fetch_data import load_all_raw

raw_data = load_all_raw()

# %%
from src.data.preprocess import stationarity_report, preprocess_all

report_df = stationarity_report(raw_data)
report_df
# Out:
#                ADF_Stat   P_Value  IsStationary  D_Order
# Ticker
# HDFCBANK.NS     -1.3959  0.584254         False        1
# ICICIBANK.NS    -1.1115  0.710450         False        1
# TCS.NS          -2.2776  0.179305         False        1
# INFY.NS         -2.3999  0.141753         False        1
# SUNPHARMA.NS    -0.8476  0.804731         False        1
# DRREDDY.NS      -1.2792  0.638636         False        1
# HINDUNILVR.NS   -2.8814  0.047548          True        0
# ITC.NS          -1.3689  0.597081         False        1
# MARUTI.NS        0.4875  0.984489         False        1
